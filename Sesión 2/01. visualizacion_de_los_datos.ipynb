# %% [markdown]
# ## *01. Visualización de los datos*
# * La visualización de datos es el proceso de representar datos y la información contenida en ellos de una manera visual y gráfica, para que puedan ser comprendidos de manera más fácil y rápida. La visualización de datos se utiliza en muchos campos, incluyendo la ciencia de datos, la estadística, la investigación de mercado, la inteligencia empresarial, entre otros.
#
# * Las ventajas de la visualización de datos incluyen:
#
#     * Comprender y comunicar patrones y relaciones complejas en los datos de manera más rápida y efectiva.
#     * Descubrir información y conocimientos nuevos y valiosos a partir de los datos.
#     * Identificar problemas y oportunidades de manera más fácil y rápida.
#     * Identificar y solucionar errores en los datos.
#     * Mejorar la comunicación y la colaboración entre los usuarios que trabajan con los datos.

# %%
# Librerías
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# Rutas de los archivos
file_path = '../datasets/adult.data'
col_names = pd.read_csv('../datasets/col_names.txt').T.iloc[0].tolist()

# Lectura de los datos
data = pd.read_csv(filepath_or_buffer=file_path,
                   names=col_names)

# %%
# Visualización de las primeras 5 filas del dataset
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# Visualización de las últimas 5 filas del dataset
data.tail()
# Out:
#        age      workclass  fnlwgt    education  education-num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# 32556             0             0              38   United-States   <=50K
# 32557             0             0              40   United-States    >50K
# 32558             0             0              40   United-States   <=50K
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K

# %%
# Visualización aleatoria de 5 filas del dataset
data.sample(5)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 8210    31            Private   35378   Some-college             10
# 1932    28            Private  162551        7th-8th              4
# 18889   26            Private  162312   Some-college             10
# 15822   24            Private  169532     Assoc-acdm             12
# 20807   55   Self-emp-not-inc  184702        HS-grad              9
#
#             marital-status          occupation     relationship  \
# 8210              Divorced        Adm-clerical    Not-in-family
# 1932    Married-civ-spouse   Machine-op-inspct   Other-relative
# 18889        Never-married        Adm-clerical    Not-in-family
# 15822        Never-married        Adm-clerical        Own-child
# 20807   Married-civ-spouse               Sales          Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 8210                 White   Female             0             0
# 1932    Asian-Pac-Islander   Female             0             0
# 18889   Asian-Pac-Islander     Male             0             0
# 15822                White   Female             0             0
# 20807                White     Male             0             0
#
#        hours-per-week  native-country  income
# 8210               45   United-States   <=50K
# 1932               48           China   <=50K
# 18889              20     Philippines   <=50K
# 15822              15   United-States   <=50K
# 20807              40   United-States   <=50K

# %%
# Forma
data.shape
# Out:
# (32561, 15)

# %%
# Índice
data.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
# Columnas
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# ### *Indexación*

# %%
# Indexación de filas de la 10 a la 20
data[10:21]
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
# 15   34            Private  245487        7th-8th              4
# 16   25   Self-emp-not-inc  176756        HS-grad              9
# 17   32            Private  186824        HS-grad              9
# 18   38            Private   28887           11th              7
# 19   43   Self-emp-not-inc  292175        Masters             14
# 20   40            Private  193524      Doctorate             16
#
#          marital-status          occupation    relationship  \
# 10   Married-civ-spouse     Exec-managerial         Husband
# 11   Married-civ-spouse      Prof-specialty         Husband
# 12        Never-married        Adm-clerical       Own-child
# 13        Never-married               Sales   Not-in-family
# 14   Married-civ-spouse        Craft-repair         Husband
# 15   Married-civ-spouse    Transport-moving         Husband
# 16        Never-married     Farming-fishing       Own-child
# 17        Never-married   Machine-op-inspct       Unmarried
# 18   Married-civ-spouse               Sales         Husband
# 19             Divorced     Exec-managerial       Unmarried
# 20   Married-civ-spouse      Prof-specialty         Husband
#
#                    race      sex  capital-gain  capital-loss  hours-per-week  \
# 10                Black     Male             0             0              80
# 11   Asian-Pac-Islander     Male             0             0              40
# 12                White   Female             0             0              30
# 13                Black     Male             0             0              50
# 14   Asian-Pac-Islander     Male             0             0              40
# 15   Amer-Indian-Eskimo     Male             0             0              45
# 16                White     Male             0             0              35
# 17                White     Male             0             0              40
# 18                White     Male             0             0              50
# 19                White   Female             0             0              45
# 20                White     Male             0             0              60
#
#     native-country  income
# 10   United-States    >50K
# 11           India    >50K
# 12   United-States   <=50K
# 13   United-States   <=50K
# 14               ?    >50K
# 15          Mexico   <=50K
# 16   United-States   <=50K
# 17   United-States   <=50K
# 18   United-States   <=50K
# 19   United-States    >50K
# 20   United-States    >50K

# %%
# Indexar una columna
data['education']
# Out:
# 0          Bachelors
# 1          Bachelors
# 2            HS-grad
# 3               11th
# 4          Bachelors
#             ...
# 32556     Assoc-acdm
# 32557        HS-grad
# 32558        HS-grad
# 32559        HS-grad
# 32560        HS-grad
# Name: education, Length: 32561, dtype: object

# %%
# Indexación por posición
data.iloc[[0]]
# Out:
#    age   workclass  fnlwgt   education  education-num  marital-status  \
# 0   39   State-gov   77516   Bachelors             13   Never-married
#
#       occupation    relationship    race    sex  capital-gain  capital-loss  \
# 0   Adm-clerical   Not-in-family   White   Male          2174             0
#
#    hours-per-week  native-country  income
# 0              40   United-States   <=50K

# %%
# Indexación por posición
data.iloc[[1337]]
# Out:
#       age workclass  fnlwgt education  education-num       marital-status  \
# 1337   40   Private  240124   HS-grad              9   Married-civ-spouse
#
#             occupation relationship    race    sex  capital-gain  \
# 1337   Exec-managerial      Husband   White   Male             0
#
#       capital-loss  hours-per-week  native-country income
# 1337             0              40   United-States   >50K

# %%
# Indexación por etiqueta
# Todas las filas de las columnas "education", "marital-status" y "relationship"
data.loc[:, ['education', 'marital-status', 'relationship']]
# Out:
#          education       marital-status    relationship
# 0        Bachelors        Never-married   Not-in-family
# 1        Bachelors   Married-civ-spouse         Husband
# 2          HS-grad             Divorced   Not-in-family
# 3             11th   Married-civ-spouse         Husband
# 4        Bachelors   Married-civ-spouse            Wife
# ...            ...                  ...             ...
# 32556   Assoc-acdm   Married-civ-spouse            Wife
# 32557      HS-grad   Married-civ-spouse         Husband
# 32558      HS-grad              Widowed       Unmarried
# 32559      HS-grad        Never-married       Own-child
# 32560      HS-grad   Married-civ-spouse            Wife
#
# [32561 rows x 3 columns]

# %%
# Primer valor de la columna "education"
data.loc[0, 'education']
# Out:
# ' Bachelors'

# %%
# Las primeras 10 filas de las columnas "education", "marital-status" y "relationship"
data.loc[0:10, ['education', 'marital-status', 'relationship']]
# Out:
#         education          marital-status    relationship
# 0       Bachelors           Never-married   Not-in-family
# 1       Bachelors      Married-civ-spouse         Husband
# 2         HS-grad                Divorced   Not-in-family
# 3            11th      Married-civ-spouse         Husband
# 4       Bachelors      Married-civ-spouse            Wife
# 5         Masters      Married-civ-spouse            Wife
# 6             9th   Married-spouse-absent   Not-in-family
# 7         HS-grad      Married-civ-spouse         Husband
# 8         Masters           Never-married   Not-in-family
# 9       Bachelors      Married-civ-spouse         Husband
# 10   Some-college      Married-civ-spouse         Husband

# %% [markdown]
# ### *Indexación (filtrado) por condiciones*

# %%
data['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
data[data.loc[:, 'marital-status'] == 'Separated']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
# La celda anterior devuelve un Dataframe vacío, ¿Por qué?
data.loc[:, 'marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data[data.loc[:, 'marital-status'] == ' Separated']
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 21      54            Private  302146        HS-grad              9
# 43      49            Private   94638        HS-grad              9
# 71      31            Private  309974      Bachelors             13
# 157     71   Self-emp-not-inc  494223   Some-college             10
# 159     42            Private  228456      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32481   52            Private  301229      Assoc-voc             11
# 32509   32            Private  192965        HS-grad              9
# 32529   29            Private  125976        HS-grad              9
# 32540   45          State-gov  252208        HS-grad              9
# 32541   41                  ?  202822        HS-grad              9
#
#       marital-status      occupation     relationship    race      sex  \
# 21         Separated   Other-service        Unmarried   Black   Female
# 43         Separated    Adm-clerical        Unmarried   White   Female
# 71         Separated           Sales        Own-child   Black   Female
# 157        Separated           Sales        Unmarried   Black     Male
# 159        Separated   Other-service   Other-relative   Black     Male
# ...              ...             ...              ...     ...      ...
# 32481      Separated           Sales        Unmarried   White   Female
# 32509      Separated           Sales    Not-in-family   White   Female
# 32529      Separated           Sales        Unmarried   White   Female
# 32540      Separated    Adm-clerical        Own-child   White   Female
# 32541      Separated               ?    Not-in-family   Black   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# 21                0             0              20   United-States   <=50K
# 43                0             0              40   United-States   <=50K
# 71                0             0              40   United-States   <=50K
# 157               0          1816               2   United-States   <=50K
# 159               0             0              50   United-States   <=50K
# ...             ...           ...             ...             ...     ...
# 32481             0             0              40   United-States   <=50K
# 32509             0             0              45   United-States   <=50K
# 32529             0             0              35   United-States   <=50K
# 32540             0             0              40   United-States   <=50K
# 32541             0             0              32   United-States   <=50K
#
# [1025 rows x 15 columns]

# %%
data[data.loc[:, 'marital-status'] == ' Widowed']
# Out:
#        age   workclass  fnlwgt   education  education-num marital-status  \
# 147     36     Private  108293     HS-grad              9        Widowed
# 167     46   State-gov  102628     Masters             14        Widowed
# 169     66   Local-gov   54826   Assoc-voc             11        Widowed
# 228     75     Private  314209   Assoc-voc             11        Widowed
# 252     59   Local-gov  171328        10th              6        Widowed
# ...    ...         ...     ...         ...            ...            ...
# 32445   61     Private  190682     HS-grad              9        Widowed
# 32446   53     Private  158993     HS-grad              9        Widowed
# 32460   62     Private  128092     HS-grad              9        Widowed
# 32465   66     Private  269665     HS-grad              9        Widowed
# 32558   58     Private  151910     HS-grad              9        Widowed
#
#                occupation    relationship    race      sex  capital-gain  \
# 147         Other-service       Unmarried   White   Female             0
# 167       Protective-serv       Unmarried   White     Male             0
# 169        Prof-specialty   Not-in-family   White   Female             0
# 228          Adm-clerical   Not-in-family   White   Female             0
# 252         Other-service       Unmarried   Black   Female             0
# ...                   ...             ...     ...      ...           ...
# 32445        Craft-repair   Not-in-family   Black   Female             0
# 32446   Machine-op-inspct       Unmarried   Black   Female             0
# 32460        Adm-clerical   Not-in-family   White   Female             0
# 32465     Exec-managerial   Not-in-family   White   Female             0
# 32558        Adm-clerical       Unmarried   White   Female             0
#
#        capital-loss  hours-per-week  native-country  income
# 147               0              24   United-States   <=50K
# 167               0              40   United-States   <=50K
# 169               0              20   United-States   <=50K
# 228               0              20        Columbia   <=50K
# 252               0              30   United-States   <=50K
# ...             ...             ...             ...     ...
# 32445          1669              50   United-States   <=50K
# 32446             0              38   United-States   <=50K
# 32460             0              32   United-States   <=50K
# 32465             0              25   United-States   <=50K
# 32558             0              40   United-States   <=50K
#
# [993 rows x 15 columns]

# %%
# Mujeres mayores de edad que trabajan 40 horas o más
data.loc[(data.loc[:, 'age'] >= 18) &
         (data.loc[:, 'sex'] == ' Female') &
         (data.loc[:, 'hours-per-week'] >= 40)]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 8       31            Private   45781        Masters             14
# 19      43   Self-emp-not-inc  292175        Masters             14
# 24      59            Private  109015        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32543   45          Local-gov  119199     Assoc-acdm             12
# 32546   37            Private  198216     Assoc-acdm             12
# 32549   43          State-gov  255835   Some-college             10
# 32558   58            Private  151910        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status        occupation     relationship    race  \
# 4       Married-civ-spouse    Prof-specialty             Wife   Black
# 5       Married-civ-spouse   Exec-managerial             Wife   White
# 8            Never-married    Prof-specialty    Not-in-family   White
# 19                Divorced   Exec-managerial        Unmarried   White
# 24                Divorced      Tech-support        Unmarried   White
# ...                    ...               ...              ...     ...
# 32543             Divorced    Prof-specialty        Unmarried   White
# 32546             Divorced      Tech-support    Not-in-family   White
# 32549             Divorced      Adm-clerical   Other-relative   White
# 32558              Widowed      Adm-clerical        Unmarried   White
# 32560   Married-civ-spouse   Exec-managerial             Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 4       Female             0             0              40            Cuba
# 5       Female             0             0              40   United-States
# 8       Female         14084             0              50   United-States
# 19      Female             0             0              45   United-States
# 24      Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32543   Female             0             0              48   United-States
# 32546   Female             0             0              40   United-States
# 32549   Female             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 4       <=50K
# 5       <=50K
# 8        >50K
# 19       >50K
# 24      <=50K
# ...       ...
# 32543   <=50K
# 32546   <=50K
# 32549   <=50K
# 32558   <=50K
# 32560    >50K
#
# [6647 rows x 15 columns]

# %%
# Insight 1
print(f"""De la muestra total que se encuentran en nuestro dataset podemos afirmar que el {(6647 / data.shape[0] * 100):0.2f}% son mujeres mayores de edad que trabajan 40 horas o más""")
# Out:
# De la muestra total que se encuentran en nuestro dataset podemos afirmar que el 20.41% son mujeres mayores de edad que trabajan 40 horas o más

# %%
# Hombres que viven en México y que trabajen como Tech-support
data.loc[(data.loc[:, 'sex'] == ' Male') &
         (data.loc[:, 'native-country'] == ' Mexico') &
         (data.loc[:, 'occupation'] == ' Tech-support')]
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 6040    25   Private  306352      Assoc-voc             11
# 23723   25   Private  245628   Some-college             10
# 32031   35   Private  195516        7th-8th              4
#
#             marital-status     occupation relationship    race    sex  \
# 6040    Married-civ-spouse   Tech-support      Husband   White   Male
# 23723        Never-married   Tech-support    Own-child   White   Male
# 32031   Married-civ-spouse   Tech-support      Husband   White   Male
#
#        capital-gain  capital-loss  hours-per-week native-country  income
# 6040              0             0              40         Mexico   <=50K
# 23723             0             0              15         Mexico   <=50K
# 32031             0             0              40         Mexico   <=50K

# %%
# Insight 2
print(f"""De la muestra total que se encuentran en nuestro dataset podemos afirmar que el {(3 / data.shape[0] * 100):0.2f}% son hombres que viven en México y que trabajen como Tech-support""")
# Out:
# De la muestra total que se encuentran en nuestro dataset podemos afirmar que el 0.01% son hombres que viven en México y que trabajen como Tech-support

# %% [markdown]
# ---
# ---
